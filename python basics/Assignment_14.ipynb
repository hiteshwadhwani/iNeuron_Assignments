# %% [markdown]
# # Assignment_14

# %% [markdown]
# ## Libraries Used - PIL (python image processing library pillow)

# %% [markdown]
# ### 1. What does RGBA stand for?

# %%
"""RDBA is the extension of RGB(red,green,blue) color value with an alpha channel which defines the opacity (0.0 - 1.0)"""

# %% [markdown]
# ### 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 2.0/2.0 MB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.1
#     Uninstalling pip-22.2.1:
#       Successfully uninstalled pip-22.2.1
# ...

# %%
from PIL import Image,ImageColor

# %%
data = img.getdata()

# %%
l = []
for i in data:
    l.append(i)

# %%
l
# Out:
# [(199, 192, 173, 255),
#  (199, 192, 173, 255),
#  (199, 192, 173, 255),
#  (200, 192, 172, 255),
#  (200, 192, 171, 255),
#  (201, 192, 170, 255),
#  (201, 192, 169, 255),
#  (202, 192, 168, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 191, 167, 255),
#  (202, 191, 166, 255),
#  (201, 191, 166, 255),
#  (202, 191, 166, 255),
#  (202, 191, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (202, 192, 167, 255),
#  (203, 192, 167, 255),
#  (203, 192, 168, 255),
#  (204, 193, 168, 255),
#  (204, 193, 168, 255),
#  (204, 193, 168, 255),
# ...

# %% [markdown]
# ### 3. What is a box tuple, and how does it work?

# %%
"""box tuple is a tuple containing four integers (left,top,right,bottom).every pillow function takes box tuple as argument"""

# %% [markdown]
# ### 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
img = Image.open('sample.png')
img.size
# Out:
# (1280, 902)

# %% [markdown]
# ### 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
img = Image.new('RGBA', (100, 100),'white')

# %%
img.show()

# %% [markdown]
# ### 6. After making changes to an Image object, how could you save it as an image file?

# %%
img.save('white.png')

# %% [markdown]
# ### 7. What module contains Pillow’s shape-drawing code?

# %%
"""Image draw module of PIL"""

# %% [markdown]
# ### 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
from PIL import ImageDraw

# %%
with Image.open('white.png').convert("RGBA") as img:
    obj = ImageDraw.Draw(img)
    obj.text((10, 10), "hitesh wadhwani", fill=(0, 0, 0))
    img.save('white1.png')
